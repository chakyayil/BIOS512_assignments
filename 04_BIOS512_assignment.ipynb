# %% [markdown]
# # BIOS512 Assignment #4

# %% [markdown]
# 🌬 For this assignment we are going to work with [Canada wind turbine](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-10-27/readme.md) data from TidyTuesday. 💨

# %% [markdown]
# Use `read_csv` to load the data from the TidyTuesday GitHub repository. The project URL is can be found at [https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-10-27/](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-10-27/).

# %%
library('tidyverse')
# Out:
# Warning message:
# “Failed to locate timezone database”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
turbine_df = read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-10-27/wind-turbine.csv')
turbine_df |> head()
# Out:
# Rows: 6698 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (8): province_territory, project_name, turbine_identifier, turbine_numbe...
# dbl (7): objectid, total_project_capacity_mw, turbine_rated_capacity_k_w, ro...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   objectid province_territory project_name           total_project_capacity_mw
# 1 1        Alberta            Optimist Wind Energy    0.90
# 2 2        Alberta            Castle River Wind Farm 44.00
# 3 3        Alberta            Waterton Wind Turbines  3.78
# 4 4        Alberta            Waterton Wind Turbines  3.78
# 5 5        Alberta            Waterton Wind Turbines  3.78
# 6 6        Alberta            Waterton Wind Turbines  3.78
#   turbine_identifier turbine_number_in_project turbine_rated_capacity_k_w
# ...

# %% [markdown]
# Each row in the table represents a single turbine.

# %% [markdown]
# Make a bar chart 📊 **sorted by frequency** of turbine count per province territory. (Hint: `fct_infreq` will sort your factor levels by frequency for subsequent plotting)

# %%
turbine_df |> pull('province_territory') |> fct_infreq() |> levels()
# Out:
#  [1] "Ontario"                   "Quebec"
#  [3] "Alberta"                   "Nova Scotia"
#  [5] "British Columbia"          "Saskatchewan"
#  [7] "Manitoba"                  "New Brunswick"
#  [9] "Prince Edward Island"      "Newfoundland and Labrador"
# [11] "Northwest Territories"     "Yukon"

# %%
options(repr.plot.width = 6, repr.plot.height = 3, repr.plot.res = 300)
turbine_sorted = turbine_df |> 
    mutate(province = province_territory |> fct_infreq() |> fct_rev())

p = ggplot(turbine_sorted, aes(y = province)) + 
    geom_bar()
p
# Out:
# plot without title

# %% [markdown]
# Make a bar chart **sorted by frequency** of turbine count per manufacturer. **Group the low frequency manufacturers into an `Other` category**.
#
# **Bonus:** Can you force the `Other` category to be the last bar?

# %%
turbine_df |> count(manufacturer) |> arrange(n)
# Out:
#    manufacturer             n
# 1  Leitwind                    1
# 2  Pfleiderer                  1
# 3  Tacke                       1
# 4  Bonus                       2
# 5  EWT                         2
# 6  Lagerwey                    2
# 7  Northwind                   3
# 8  Turbowinds                  3
# 9  Samsung Renewable Energy    4
# 10 DeWind                      5
# 11 Windmatic                   6
# 12 Gamesa                      8
# 13 Vensys                      9
# 14 Suzlon                     15
# 15 Nordex                     20
# 16 Acciona                    34
# 17 Acciona Wind Power         40
# 18 NEG Micon                 132
# 19 Senvion                   643
# 20 Enercon                   960
# 21 Siemens                  1248
# 22 GE                       1725
# 23 Vestas                   1834

# %%
turbine_lumped = turbine_df |> 
    mutate(manufacturer_lumped = manufacturer |> fct_lump_min(500) |> fct_infreq() |> fct_rev()) 

p = ggplot(turbine_lumped, aes(y = manufacturer_lumped)) + 
    geom_bar()
p
# Out:
# plot without title
